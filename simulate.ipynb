# %%
import src.strategies
import src.blackjack
import src.monte_carlo

# %%
#choose the specifications for the simulation and the strategy to simulate with:
simulation = src.blackjack.Simulation(performance_mode=True, finite_deck=False, 
                           num_of_decks=6, penetration=0.7 , 
                           bets_active=True, bankroll=1000000, 
                           dealer_hit_17=True, blackjack_payout=1.5)
strategy = src.strategies.basic_test

src.monte_carlo.monte_carlo(simulation, strategy, mc_runs=100, bj_rounds=10000, plot=True, plot_points=500)
# Out:
# Finished
# --------Monte Carlo Simulation Results--------
# EV (Profit/Hand): -2.99
# EV Std Dev: 0.44
# EV 95% CI: [-3.08, -2.91]
# House Edge: 5.99%
# Avg Bet: 50.0
# Avg Total Profit: -29934.75
# ROI: -2.99%
# RoR: 0.0
# Winrate: 41.03%
# Effective Winrate: 45.44%
# Lossrate: 49.28%
# Pushrate: 9.69%
# Blackjacks: 4.73%
# Avg Min Bankroll: 969699.5
# Worst Min Bankroll: 957300.0
# Max Drawdown: -4.3%
# Avg Max Drawdown: -3.07%
